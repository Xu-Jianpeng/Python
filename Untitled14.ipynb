# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook
pd.options.display.max_rows = 35

alldata=csv.reader(open('D:/new/地区人口总数分省年度数据.csv','r'))
#alldata = pd.read_table('C:/Users/Administrator/Desktop/Python课件与书籍/地区生产总值季度数据.csv')#,sep='::',header=None,names=pnames)
alldata
alldata_panda=pd.DataFrame(alldata)
alldata_panda
database1=pd.DataFrame(alldata_panda.drop([0,1,2,35,36]))
database=pd.DataFrame(database1.drop([0],1))
database.index=database1[0][:32]
database.columns=database1.T[3][1:11]
database
database=pd.DataFrame(database.drop(['地区']))
database=database.astype('float')#强制类型转换
databaseT=database.T
databaseT.columns=['北京','天津','河北','山西','内蒙古','辽宁','吉林','黑龙江','上海','江苏', '浙江', '安徽', '福建', '江西', '山东', '河南', '湖北', '湖南', '广东',
                 '广西', '海南', '重庆', '四川', '贵州', '云南', '西藏', '陕西', '甘肃','青海', '宁夏', '新疆']
databaseT.sort_values(by='2018年',axis=1)
# Out:
#           西藏     青海     宁夏     海南      天津      北京      上海      新疆     内蒙古  \
# 3
# 2018年  344.0  603.0  688.0  934.0  1560.0  2154.0  2424.0  2487.0  2534.0
# 2017年  337.0  598.0  682.0  926.0  1557.0  2171.0  2418.0  2445.0  2529.0
# 2016年  331.0  593.0  675.0  917.0  1562.0  2173.0  2420.0  2398.0  2520.0
# 2015年  324.0  588.0  668.0  911.0  1547.0  2171.0  2415.0  2360.0  2511.0
# 2014年  318.0  583.0  662.0  903.0  1517.0  2152.0  2426.0  2298.0  2505.0
# 2013年  312.0  578.0  654.0  895.0  1472.0  2115.0  2415.0  2264.0  2498.0
# 2012年  308.0  573.0  647.0  887.0  1413.0  2069.0  2380.0  2233.0  2490.0
# 2011年  303.0  568.0  639.0  877.0  1355.0  2019.0  2347.0  2209.0  2482.0
# 2010年  300.0  563.0  633.0  869.0  1299.0  1962.0  2303.0  2185.0  2472.0
# 2009年  296.0  557.0  625.0  864.0  1228.0  1860.0  2210.0  2159.0  2458.0
#
#            甘肃  ...      浙江      湖北      安徽      湖南      河北      江苏      四川  \
# 3              ...
# 2018年  2637.0  ...  5737.0  5917.0  6324.0  6899.0  7556.0  8051.0  8341.0
# 2017年  2626.0  ...  5657.0  5902.0  6255.0  6860.0  7520.0  8029.0  8302.0
# 2016年  2610.0  ...  5590.0  5885.0  6196.0  6822.0  7470.0  7999.0  8262.0
# 2015年  2600.0  ...  5539.0  5852.0  6144.0  6783.0  7425.0  7976.0  8204.0
# 2014年  2591.0  ...  5508.0  5816.0  6083.0  6737.0  7384.0  7960.0  8140.0
# 2013年  2582.0  ...  5498.0  5799.0  6030.0  6691.0  7333.0  7939.0  8107.0
# 2012年  2578.0  ...  5477.0  5779.0  5988.0  6639.0  7288.0  7920.0  8076.0
# 2011年  2564.0  ...  5463.0  5758.0  5968.0  6596.0  7241.0  7899.0  8050.0
# 2010年  2560.0  ...  5447.0  5728.0  5957.0  6570.0  7194.0  7869.0  8045.0
# 2009年  2555.0  ...  5276.0  5720.0  6131.0  6406.0  7034.0  7810.0  8185.0
#
#            河南       山东       广东
# 3
# 2018年  9605.0  10047.0  11346.0
# 2017年  9559.0  10006.0  11169.0
# 2016年  9532.0   9947.0  10999.0
# 2015年  9480.0   9847.0  10849.0
# 2014年  9436.0   9789.0  10724.0
# 2013年  9413.0   9733.0  10644.0
# 2012年  9406.0   9685.0  10594.0
# 2011年  9388.0   9637.0  10505.0
# 2010年  9405.0   9588.0  10441.0
# 2009年  9487.0   9470.0  10130.0
#
# [10 rows x 31 columns]

# %%
from pyecharts.charts import Map
from example.commons import Faker
from pyecharts import options as opts

def map_visualmap() -> Map:
    c = (
        Map()
        .add("人口总数（万人）", [list(z) for z in zip(attr,values)], "china")
        .set_global_opts(
            title_opts=opts.TitleOpts(title="地区人口总数2018年（万人）"),
            visualmap_opts=opts.VisualMapOpts(min_=344,max_=11346)#, is_piecewise=True),
        )
    )
    return c
attr=list(databaseT.columns)
values=databaseT.values.tolist()[0]
print(attr)
print(values)
#list(z) for z in zip(attr,values)
z = list(zip(attr,values))
print(z)
#map1=Map()
#map1=Map("各省GDP总值", '单位：亿元',width=1200,height=600)
#map1.add("", attr, values, type="effectScatter", is_random=True, visual_range=[0, 100], 
 #       maptype='china', geo_emphasis_color='#F5D0A9',visual_text_color="#6E6E6E",
 #        is_visualmap=True, is_map_symbol_show=False)
map1=map_visualmap()
map1.render('C:\\Users\\Administrator\\render_population.html')
# Out:
# ['北京', '天津', '河北', '山西', '内蒙古', '辽宁', '吉林', '黑龙江', '上海', '江苏', '浙江', '安徽', '福建', '江西', '山东', '河南', '湖北', '湖南', '广东', '广西', '海南', '重庆', '四川', '贵州', '云南', '西藏', '陕西', '甘肃', '青海', '宁夏', '新疆']
# [2154.0, 1560.0, 7556.0, 3718.0, 2534.0, 4359.0, 2704.0, 3773.0, 2424.0, 8051.0, 5737.0, 6324.0, 3941.0, 4648.0, 10047.0, 9605.0, 5917.0, 6899.0, 11346.0, 4926.0, 934.0, 3102.0, 8341.0, 3600.0, 4830.0, 344.0, 3864.0, 2637.0, 603.0, 688.0, 2487.0]
# [('北京', 2154.0), ('天津', 1560.0), ('河北', 7556.0), ('山西', 3718.0), ('内蒙古', 2534.0), ('辽宁', 4359.0), ('吉林', 2704.0), ('黑龙江', 3773.0), ('上海', 2424.0), ('江苏', 8051.0), ('浙江', 5737.0), ('安徽', 6324.0), ('福建', 3941.0), ('江西', 4648.0), ('山东', 10047.0), ('河南', 9605.0), ('湖北', 5917.0), ('湖南', 6899.0), ('广东', 11346.0), ('广西', 4926.0), ('海南', 934.0), ('重庆', 3102.0), ('四川', 8341.0), ('贵州', 3600.0), ('云南', 4830.0), ('西藏', 344.0), ('陕西', 3864.0), ('甘肃', 2637.0), ('青海', 603.0), ('宁夏', 688.0), ('新疆', 2487.0)]
# 'C:\\Users\\Administrator\\render_population.html'
