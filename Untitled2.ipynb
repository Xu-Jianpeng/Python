# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook
pd.options.display.max_rows = 35

alldata=csv.reader(open('C:/Users/Administrator/Desktop/Python课件与书籍/地区生产总值季度数据.csv','r'))
#alldata = pd.read_table('C:/Users/Administrator/Desktop/Python课件与书籍/地区生产总值季度数据.csv')#,sep='::',header=None,names=pnames)
alldata
alldata_panda=pd.DataFrame(alldata)
database1=pd.DataFrame(alldata_panda.drop([0,1,2,3,35]))
database=pd.DataFrame(database1.drop([0],1))
database=database.astype('float')#强制类型转换

# %%
database.index=[database1[0]]#['BJ','TJ','HB','SX1','NMG','LN','JL','HLJ','SH','JS','ZJ','AH','FJ','JX',"SD",'HN','HUB','HUN','GD','GX','HAIN','CQ','SC','GZ','YN','XZ','SX3','GS','QH','NX',"XJ"]
database.columns=['20191','20184','20183','20182','20181','20174','20173','20172','20171','20164','20163','20162','20161','20154','20153','20152','20151','20149']

databaseT=database.T[::-1]
databaseT
# Out:
# 0           北京市       天津市       河北省       山西省    内蒙古自治区       辽宁省       吉林省  \
# 20191   7409.61   5198.58   8164.42   3533.21   3578.53   5486.21   2701.76
# 20184  30319.98  18809.64  36010.27  16818.11  17289.22  25315.35  15074.62
# 20183  21511.11  14658.36  25226.33  11640.33  12309.17  18012.38   9957.68
# 20182  14051.23   9927.60  16600.54   7482.75   7776.67  11383.28   6299.07
# 20181   6801.47   4959.42   7564.02   3122.07   3290.47   5125.03   2659.29
# 20174  28000.35  18595.38  35964.00  14973.51  16103.17  23942.00  15288.94
# 20173  19569.76  13449.50  25603.47  10460.38  13740.21  16639.40   9970.58
# 20172  12406.79   9386.87  16404.87   6577.91   8465.71  10296.82   6124.22
# 20171   6040.48   4667.18   7512.43   2809.42   3742.20   4574.72   2683.43
# 20164  24899.26  17885.39  31827.86  12928.34  18632.57  22037.88  14886.23
# 20163  17367.77  13339.44  22496.12   8945.55  12690.14  19952.81   9298.11
# ...

# %%
databaseT.plot()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1, 1, 1)
#ax2 = fig.add_subplot(1, 2, 2)
#%matplotlib notebook

ax1.plot(range(18),databaseT['BJ'],'b.--')
ax1.plot(range(18),databaseT['GD'],'r.--')
ax1.plot(range(18),databaseT['GX'],'g.--')
#ax2.hist(data['Rebound'],color='r')
#ax1.scatter(data.index+1,data['Assist'])#, 'g--')
ax1.legend(loc='best')
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
databaseT_sort=databaseT.sort_values(by='20191',axis=1,ascending=False)
databaseT_sorted=databaseT_sort[databaseT_sort.index=='20191']
databaseT_sort.T[20:]
databaseT_sorted.columns=['广东','江苏','山东','浙江','河南','四川','湖北','湖南','上海','河北','福建','北京','安徽','辽宁','陕西','江西','天津','重庆','广西','云南','内蒙古','山西','贵州','黑龙江','吉林','新疆','甘肃','海南','宁夏','青海','西藏']
databaseT_sorted
# Out:
#              广东        江苏        山东        浙江        河南       四川       湖北  \
# 20191  23886.77  22883.79  20177.39  13084.07  11639.05  9653.18  9110.05
#
#             湖南       上海       河北  ...       山西       贵州      黑龙江       吉林  \
# 20191  8334.97  8308.28  8164.42  ...  3533.21  3205.75  3184.57  2701.76
#
#             新疆       甘肃       海南      宁夏      青海      西藏
# 20191  2177.69  1736.54  1300.32  752.37  557.09  324.08
#
# [1 rows x 31 columns]

# %%
from pyecharts.charts import Map
from example.commons import Faker
from pyecharts import options as opts

def map_visualmap() -> Map:
    c = (
        Map()
        .add("GDP", [list(z) for z in zip(attr,values)], "china")
        .set_global_opts(
            title_opts=opts.TitleOpts(title="地区生产总值2019年第一季度"),
            visualmap_opts=opts.VisualMapOpts(min_=8000,max_=24000）#
                                              
                                              
                                              , is_piecewise=True),
        )
    )
    return c
attr=list(databaseT_sorted.columns)[:10]
values=databaseT_sorted.values.tolist()[0]
print(attr)
print(values)
#list(z) for z in zip(attr,values)
z = list(zip(attr,values))
print(z)
#map1=Map()
#map1=Map("各省GDP总值", '单位：亿元',width=1200,height=600)
#map1.add("", attr, values, type="effectScatter", is_random=True, visual_range=[0, 100], 
 #       maptype='china', geo_emphasis_color='#F5D0A9',visual_text_color="#6E6E6E",
 #        is_visualmap=True, is_map_symbol_show=False)
map1=map_visualmap()
map1.render()
# Out:
# ['广东', '江苏', '山东', '浙江', '河南', '四川', '湖北', '湖南', '上海', '河北']
# [23886.77, 22883.79, 20177.39, 13084.07, 11639.05, 9653.18, 9110.05, 8334.97, 8308.28, 8164.42, 8145.25, 7409.61, 7065.71, 5486.21, 5450.34, 5373.1, 5198.58, 5102.3, 4225.32, 3849.65, 3578.53, 3533.21, 3205.75, 3184.57, 2701.76, 2177.69, 1736.54, 1300.32, 752.37, 557.09, 324.08]
# [('广东', 23886.77), ('江苏', 22883.79), ('山东', 20177.39), ('浙江', 13084.07), ('河南', 11639.05), ('四川', 9653.18), ('湖北', 9110.05), ('湖南', 8334.97), ('上海', 8308.28), ('河北', 8164.42)]
# 'C:\\Users\\Administrator\\render.html'
