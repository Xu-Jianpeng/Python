# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook
pd.options.display.max_rows = 35

alldata1=csv.reader(open('D:/new/地区人口总数分省年度数据.csv','r'))
#alldata = pd.read_table('C:/Users/Administrator/Desktop/Python课件与书籍/地区生产总值季度数据.csv')#,sep='::',header=None,names=pnames)
alldata1
alldata_panda1=pd.DataFrame(alldata1)
alldata_panda1
database11=pd.DataFrame(alldata_panda1.drop([0,1,2,35,36]))
database1=pd.DataFrame(database11.drop([0],1))
database1.index=database11[0][:32]
database1.columns=database11.T[3][1:11]
database1
database1=pd.DataFrame(database1.drop(['地区']))
database1=database1.astype('float')#强制类型转换
databaseT1=database1.T
databaseT1.columns=['北京','天津','河北','山西','内蒙古','辽宁','吉林','黑龙江','上海','江苏', '浙江', '安徽', '福建', '江西', '山东', '河南', '湖北', '湖南', '广东',
                 '广西', '海南', '重庆', '四川', '贵州', '云南', '西藏', '陕西', '甘肃','青海', '宁夏', '新疆']
databaseT1.sort_values(by='2018年',axis=1)
alldata2=csv.reader(open('D:/new/各省高等学校招生人数（本科）年度数据.csv','r'))
#alldata = pd.read_table('C:/Users/Administrator/Desktop/Python课件与书籍/地区生产总值季度数据.csv')#,sep='::',header=None,names=pnames)
alldata2
alldata_panda2=pd.DataFrame(alldata2)
alldata_panda2
database12=pd.DataFrame(alldata_panda2.drop([0,1,2,35]))
database2=pd.DataFrame(database12.drop([0,1],1))
database2.index=database12[0][:32]
database2.columns=database12.T[3][2:11]
database2
database2=pd.DataFrame(database2.drop(['地区']))
database2=database2.astype('float')#强制类型转换
databaseT2=database2.T
databaseT2.columns=['北京','天津','河北','山西','内蒙古','辽宁','吉林','黑龙江','上海','江苏', '浙江', '安徽', '福建', '江西', '山东', '河南', '湖北', '湖南', '广东',
                 '广西', '海南', '重庆', '四川', '贵州', '云南', '西藏', '陕西', '甘肃','青海', '宁夏', '新疆']
databaseT2.sort_values(by='2017年',axis=1)
# Out:
#          西藏    青海    宁夏     海南     新疆    内蒙古     甘肃     贵州     天津     上海  ...  \
# 3                                                                         ...
# 2017年  2.42  3.75  7.85  11.04  17.98  25.22  29.25  31.71  34.18  37.62  ...
# 2016年  2.39  3.61  7.62  10.77  16.90  24.65  29.17  30.16  33.73  37.13  ...
# 2015年  2.32  3.54  7.46  10.60  16.19  23.93  29.08  28.17  33.41  36.72  ...
# 2014年  2.22  3.43  7.16  10.47  15.51  23.48  28.84  27.34  32.92  36.47  ...
# 2013年  2.14  3.33  6.74  10.30  15.13  23.00  28.01  25.72  32.32  36.27  ...
# 2012年  2.06  3.17  6.21   9.79  14.63  22.19  26.95  22.95  31.06  35.90  ...
# 2011年  1.99  2.98  5.70   8.79  14.18  21.14  25.57  20.41  29.35  35.72  ...
# 2010年  1.97  2.81  5.12   8.03  13.94  19.76  23.84  18.44  27.36  35.49  ...
# 2009年  1.94  2.67  4.63   7.01  13.51  17.86  21.91  16.54  25.56  34.74  ...
#
#           陕西     辽宁     湖南     河北     湖北     四川      山东      河南      江苏  \
# 3
# 2017年  67.06  70.24  70.35  73.58  86.34  86.51  103.68  107.71  109.70
# 2016年  67.73  71.06  68.81  70.87  86.06  82.10  100.94  103.42  106.90
# 2015年  69.85  71.09  67.83  68.26  86.38  78.36   97.59   99.55  103.25
# 2014年  70.58  70.51  66.53  66.58  86.49  74.91   96.10   95.52  101.26
# 2013年  68.74  67.58  65.18  64.54  85.75  73.54   93.55   91.02  100.08
# 2012年  65.16  64.58  63.06  62.26  82.10  71.40   90.13   83.71   98.46
# 2011年  59.52  62.45  59.32  59.20  77.09  68.35   86.64   75.88   96.81
# 2010年  54.57  60.22  55.72  55.22  71.62  64.32   80.75   68.72   94.41
# 2009年  50.72  58.24  51.61  50.50  66.52  59.37   75.75   61.61   89.65
#
#            广东
# 3
# 2017年  110.58
# 2016年  107.68
# 2015年  104.08
# 2014年   99.82
# 2013年   94.96
# 2012年   90.04
# 2011年   84.23
# 2010年   77.86
# 2009年   71.95
#
# [9 rows x 31 columns]

# %%
attr1=list(databaseT1.columns)
values1=databaseT1.values.tolist()[0]
values1=list(np.array(values1)/sum(values1))
attr2=list(databaseT2.columns)
values2=databaseT2.values.tolist()[0]
values2=list(np.array(values2)/sum(values2))

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1, 1, 1)
#ax2 = fig.add_subplot(1, 2, 2)
#%matplotlib notebook

ax1.plot(np.arange(31),values1,'b.--',label='population')
ax1.plot(np.arange(31),values2,'r.--',label='university_population')
#ax1.plot(range(18),databaseT['GX'],'g.--')
#ax2.hist(data['Rebound'],color='r')
#ax1.scatter(data.index+1,data['Assist'])#, 'g--')
ax1.legend(loc='best')
values1
# Out:
# <img src="data:image/png;base64,..." width="640">
# [0.015423943631715753,
#  0.01117054413439024,
#  0.05410553299964913,
#  0.0266231301869634,
#  0.018144973613169784,
#  0.031213078129363494,
#  0.019362276499609747,
#  0.027016963473752802,
#  0.017357307039590986,
#  0.05765003258075373,
#  0.041080392114741536,
#  0.045283667375566584,
#  0.02821994514976406,
#  0.03328249303631143,
#  0.07194260058860175,
#  0.06877761308385785,
#  0.04236930105332503,
#  0.0494010153738194,
#  0.08124422676204593,
#  0.035273141285901484,
#  0.006688005270205437,
#  0.022212197374922128,
#  0.059726608092916016,
#  0.025778178771669782,
#  0.03458572318532362,
#  0.0024632481937373347,
#  0.0276685785482589,
#  0.018882515950248115,
#  0.004317844944254689,
#  0.004926496387474669,
#  0.017808425168095207]

# %%
import pyecharts.options as opts
from example.commons import  Faker
from pyecharts.charts import Line


def line_base() -> Line:
    c = (
        Line()
        .add_xaxis(attr1)
        .add_yaxis("人口总数占比", values1)
        .add_yaxis("本科生招生人数占比",values2)
        .set_global_opts(title_opts=opts.TitleOpts(title="人口总数与本科生招生人数关系曲线"))
    )
    return c
line1=line_base()
line1.render('C:\\Users\\Administrator\\render_关系.html')
# Out:
# 'C:\\Users\\Administrator\\render_关系.html'
